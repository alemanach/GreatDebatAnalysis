# %%
import pandas as pd 
import numpy as np 
from IPython.display import clear_output

# %%
#On importe les données disponibles ici : https://granddebat.fr/pages/donnees-ouvertes. sur la transition écologique 31 Janvier 2019
raw_data = pd.read_csv('/Volumes/Carte_SD/Arthur/FMR/Etude_de_cas/GreatDebatAnalysis/notebooks/LA_TRANSITION_ECOLOGIQUE.csv')
raw_data.head(5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   reference                  title            createdAt          publishedAt  \
# 0       2-4  transition écologique  2019-01-22 09:37:49  2019-01-22 09:37:49
# 1       2-5       La surpopulation  2019-01-22 09:39:33  2019-01-22 09:39:33
# 2       2-6                 climat  2019-01-22 09:39:50  2019-01-22 09:39:50
# 3       2-7      POLLUTION AIR EAU  2019-01-22 09:40:19  2019-01-22 09:40:19
# 4       2-8   Economie vs Ecologie  2019-01-22 09:41:33  2019-01-22 09:41:33
#
#   updatedAt  trashed trashedStatus  \
# 0       NaN    False           NaN
# 1       NaN    False           NaN
# 2       NaN    False           NaN
# 3       NaN    False           NaN
# 4       NaN    False           NaN
#
# ...

# %%
#On extrait les 2 questions qui nous intéressent
data = raw_data[['authorZipCode',"Quel est aujourd'hui pour vous le problème concret le plus important dans le domaine de l'environnement ?",'Que faudrait-il faire selon vous pour apporter des réponses à ce problème ?']]
data.head(5)
# Out:
#    authorZipCode  \
# 0          97231
# 1          57000
# 2          34140
# 3          17400
# 4          35430
#
#   Quel est aujourd'hui pour vous le problème concret le plus important dans le domaine de l'environnement ?  \
# 0                                                NaN
# 1  Les problèmes auxquels se trouve confronté l’e...
# 2    Les dérèglements climatiques (crue, sécheresse)
# 3                              La pollution de l'air
# 4  La biodiversité et la disparition de certaines...
#
#   Que faudrait-il faire selon vous pour apporter des réponses à ce problème ?
# 0                                                NaN
# 1  Les problèmes auxquels se trouve confronté l’e...
# 2  pour éviter les inondations obliger les rivera...
# 3  Il faut taxer les gros pollueurs : Entreprises...
# 4  Changer notre mode de vie, impulser une nouvel...

# %%
#On nettoie la base de donnée
no_na = data.dropna()
print(no_na.shape)
no_na[no_na.columns[2]] = no_na[no_na.columns[2]].apply(lambda x : x if len(x) > 200 else np.nan )
col_names = {
    no_na.columns[0]: 'zip_code',
     no_na.columns[1]: 'problem',
     no_na.columns[2]: 'solution'
}

clean_data = no_na.dropna()
print(clean_data.shape)
clean_data.head(5)
clean_data = clean_data.rename(columns=col_names)
clean_data.to_csv('/Volumes/Carte_SD/Arthur/FMR/Etude_de_cas/GreatDebatAnalysis/notebooks/dataset_1.csv')
# Out:
# (31775, 3)
# (15309, 3)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
clean_data.head(5)
# Out:
#     zip_code                                            problem  \
# 1      57000  Les problèmes auxquels se trouve confronté l’e...
# 5      95330                              La pollution de l'air
# 6      84750  La biodiversité et la disparition de certaines...
# 10     33820                              La pollution de l'air
# 14      8500                              Pollution air et mers
#
#                                              solution
# 1   Les problèmes auxquels se trouve confronté l’e...
# 5   En matière d'émission de C02 tout n'est pas di...
# 6   Arrêter les pesticides , notamment le glyphosa...
# 10  - Réduire de manière drastique les déplacement...
# 14  Interdire très rapidement les emballages plast...

# %%
#Ici on annote la qualité de l'argumentation
original_csv = pd.read_csv('/Volumes/Carte_SD/Arthur/FMR/Etude_de_cas/GreatDebatAnalysis/notebooks/dataset_annote.csv',index_col=0)

n = 2000
data = original_csv.head(n)

for index in range(403,n):
    value = original_csv.iloc[index]
    print('ligne numéro ',index,'\n')
    print("problème =",'\n',value[1],'\n')
    print("solutions =",'\n',value[2],'\n')        
    annot = input('Bon Argument = 1 / Mauvais ou pas d\'argument = 0 / Break = b')
    
    #Permet de reprendre l'annotation plus tard
    if annot =='b':
        break

    data.iloc[index,3]=annot
    clear_output()

data.to_csv('/Volumes/Carte_SD/Arthur/FMR/Etude_de_cas/GreatDebatAnalysis/notebooks/dataset_annote.csv')
# Out:
# ligne numéro  403
#
# problème =
#  La pollution de l'air
#
# solutions =
#  Taxer les poids lourds, privilégier le fret, augmenter les voies pietonnes et pistes cyclables, péage à l'entrée des grandes villes, développement des transports en commun, parking relais pour les vélos electriques à proximité des gares, parking relais à l'entree des grandes villes, développement de véhicules sans rejet de CO2 et particules. Plus de commerces de proximité et moins de grandes surfaces où l'on est obligé d'utiliser sa voiture
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# ...
